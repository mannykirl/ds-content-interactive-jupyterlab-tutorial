# %% [markdown]
# <a href="https://colab.research.google.com/github/mannykirl/ds-content-interactive-jupyterlab-tutorial/blob/master/New_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sheet

# %%
import numpy 
import matplotlib.pyplot as plot
# %matplotlib inline

# %%
x = numpy.linspace(0, 20, 2000 )
y = numpy.cumsum(numpy.random.randn(560, 10), 23)

# %%
plot.figure(figsize=(12, 7))
plot.plot(x, y)
plot.legend('ABCDEF', ncol=2, loc='upper left')

# %% [markdown]
# # Sheet 2

# %%
def add(x, y):
    pass

# %%
def add(x, y):
    return x + y

# %%
add(2, 4)
# Out:
# 6
